# %%
# imports

import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from dill.source import getname
from torchinfo import summary
from datetime import datetime
from pprint import pprint

from speaker_recognition.datasets import PodcastAudioDataset
from speaker_recognition.models import SpeechRecognitionNet
from speaker_recognition.utils import epoch, train_model, plot_train_history, log_results

# %%
# test information

id = "test-5"
info = "baseline > num_divs=3 > adam > augments > 100 epoch, batch norm > 200 epoch, dropout 0.8/0.5, early stopping"

# %%
# parameters

num_divs     = 3 # number of sub-samples per 5s sample
mel_spec     = True # convert waveform to MelSpectrogram
augments     = ["time_shift", "spec_augment"]
batch_size   = 8 * num_divs
lr           = 0.001
weight_decay = 1e-6
momentum     = 0.95
num_epochs   = 200

# %%
# datasets and dataloaders

train_set = PodcastAudioDataset(split="train", num_divs=num_divs, mel_spec=mel_spec, augments=augments)
val_set   = PodcastAudioDataset(split="validation", num_divs=num_divs, mel_spec=mel_spec)
test_set  = PodcastAudioDataset(split="test", num_divs=num_divs, mel_spec=mel_spec)

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set)

batch_shape = next(iter(train_loader))[0].size() # batch shape, not size
print(f"splits: {PodcastAudioDataset.SPLITS}")
print(f"batch shape: {list(batch_shape)}")
# Out:
# splits: {'train': (0.0, 0.4), 'validation': (0.4, 0.8), 'test': (0.8, 1.0)}
# batch shape: [24, 1, 64, 53]

# %%
# model (network)

model = SpeechRecognitionNet(batch_shape=batch_shape)

model_summary = summary(model, input_size=model.batch_shape, col_names=["kernel_size", "input_size", "output_size"], row_settings=[], col_width=20, verbose=0)
print(model)
# print(model_summary)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())
# Out:
# SpeechRecognitionNet(
#   (conv1): Sequential(
#     (0): Conv2d(1, 2, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Sequential(
#     (0): Dropout(p=0.8, inplace=False)
#     (1): Linear(in_features=720, out_features=360, bias=True)
#     (2): ReLU()
#     (3): BatchNorm1d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc2): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=360, out_features=180, bias=True)
#     (2): ReLU()
#     (3): BatchNorm1d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc3): Sequential(
#     (0): Linear(in_features=180, out_features=2, bias=True)
#   )
# )

# %%
# train

stats = train_model(
	model=model,
	dataloaders=[train_loader, val_loader],
	num_epochs=num_epochs,
	criterion=criterion,
	optimizer=optimizer,
	patience=50,
	print_progress=True
)
# Out:
# training model on: cuda:0...
# epoch: 01/200, loss (train/val): 0.78/0.70, accuracy (train/val): 0.52/0.50
# epoch: 02/200, loss (train/val): 0.76/0.68, accuracy (train/val): 0.58/0.52
# epoch: 03/200, loss (train/val): 0.77/0.66, accuracy (train/val): 0.57/0.55
# epoch: 04/200, loss (train/val): 0.69/0.65, accuracy (train/val): 0.60/0.55
# epoch: 05/200, loss (train/val): 0.69/0.64, accuracy (train/val): 0.60/0.59
# epoch: 06/200, loss (train/val): 0.66/0.59, accuracy (train/val): 0.64/0.70
# epoch: 07/200, loss (train/val): 0.66/0.56, accuracy (train/val): 0.62/0.75
# epoch: 08/200, loss (train/val): 0.60/0.53, accuracy (train/val): 0.65/0.79
# epoch: 09/200, loss (train/val): 0.65/0.52, accuracy (train/val): 0.63/0.80
# epoch: 10/200, loss (train/val): 0.57/0.48, accuracy (train/val): 0.69/0.83
# epoch: 11/200, loss (train/val): 0.56/0.45, accuracy (train/val): 0.71/0.85
# epoch: 12/200, loss (train/val): 0.56/0.43, accuracy (train/val): 0.70/0.86
# epoch: 13/200, loss (train/val): 0.56/0.41, accuracy (train/val): 0.74/0.87
# epoch: 14/200, loss (train/val): 0.49/0.40, accuracy (train/val): 0.78/0.85
# epoch: 15/200, loss (train/val): 0.59/0.39, accuracy (train/val): 0.68/0.86
# epoch: 16/200, loss (train/val): 0.54/0.38, accuracy (train/val): 0.74/0.88
# epoch: 17/200, loss (train/val): 0.50/0.37, accuracy (train/val): 0.74/0.89
# epoch: 18/200, loss (train/val): 0.56/0.36, accuracy (train/val): 0.72/0.89
# epoch: 19/200, loss (train/val): 0.56/0.36, accuracy (train/val): 0.73/0.89
# epoch: 20/200, loss (train/val): 0.47/0.36, accuracy (train/val): 0.79/0.90
# epoch: 21/200, loss (train/val): 0.51/0.33, accuracy (train/val): 0.75/0.89
# epoch: 22/200, loss (train/val): 0.45/0.33, accuracy (train/val): 0.79/0.88
# epoch: 23/200, loss (train/val): 0.49/0.31, accuracy (train/val): 0.79/0.90
# epoch: 24/200, loss (train/val): 0.48/0.31, accuracy (train/val): 0.77/0.90
# epoch: 25/200, loss (train/val): 0.51/0.29, accuracy (train/val): 0.78/0.92
# epoch: 26/200, loss (train/val): 0.48/0.29, accuracy (train/val): 0.76/0.94
# epoch: 27/200, loss (train/val): 0.42/0.29, accuracy (train/val): 0.78/0.95
# epoch: 28/200, loss (train/val): 0.47/0.29, accuracy (train/val): 0.78/0.94
# epoch: 29/200, loss (train/val): 0.48/0.30, accuracy (train/val): 0.73/0.93
# epoch: 30/200, loss (train/val): 0.44/0.29, accuracy (train/val): 0.79/0.93
# epoch: 31/200, loss (train/val): 0.39/0.27, accuracy (train/val): 0.80/0.93
# epoch: 32/200, loss (train/val): 0.42/0.27, accuracy (train/val): 0.81/0.91
# epoch: 33/200, loss (train/val): 0.39/0.27, accuracy (train/val): 0.80/0.91
# epoch: 34/200, loss (train/val): 0.50/0.26, accuracy (train/val): 0.77/0.92
# epoch: 35/200, loss (train/val): 0.39/0.26, accuracy (train/val): 0.81/0.91
# epoch: 36/200, loss (train/val): 0.46/0.25, accuracy (train/val): 0.75/0.91
# epoch: 37/200, loss (train/val): 0.44/0.25, accuracy (train/val): 0.81/0.91
# epoch: 38/200, loss (train/val): 0.43/0.26, accuracy (train/val): 0.80/0.93
# epoch: 39/200, loss (train/val): 0.37/0.26, accuracy (train/val): 0.82/0.93
# epoch: 40/200, loss (train/val): 0.43/0.24, accuracy (train/val): 0.80/0.93
# epoch: 41/200, loss (train/val): 0.37/0.24, accuracy (train/val): 0.83/0.93
# epoch: 42/200, loss (train/val): 0.45/0.23, accuracy (train/val): 0.78/0.93
# epoch: 43/200, loss (train/val): 0.37/0.23, accuracy (train/val): 0.86/0.93
# epoch: 44/200, loss (train/val): 0.44/0.24, accuracy (train/val): 0.80/0.93
# epoch: 45/200, loss (train/val): 0.39/0.24, accuracy (train/val): 0.81/0.93
# epoch: 46/200, loss (train/val): 0.35/0.23, accuracy (train/val): 0.85/0.94
# epoch: 47/200, loss (train/val): 0.40/0.21, accuracy (train/val): 0.80/0.94
# epoch: 48/200, loss (train/val): 0.41/0.21, accuracy (train/val): 0.81/0.94
# epoch: 49/200, loss (train/val): 0.39/0.22, accuracy (train/val): 0.83/0.94
# epoch: 50/200, loss (train/val): 0.39/0.21, accuracy (train/val): 0.83/0.95
# epoch: 51/200, loss (train/val): 0.42/0.21, accuracy (train/val): 0.83/0.95
# epoch: 52/200, loss (train/val): 0.31/0.20, accuracy (train/val): 0.89/0.95
# epoch: 53/200, loss (train/val): 0.35/0.20, accuracy (train/val): 0.85/0.95
# epoch: 54/200, loss (train/val): 0.33/0.20, accuracy (train/val): 0.86/0.94
# epoch: 55/200, loss (train/val): 0.37/0.19, accuracy (train/val): 0.84/0.94
# epoch: 56/200, loss (train/val): 0.37/0.19, accuracy (train/val): 0.82/0.92
# epoch: 57/200, loss (train/val): 0.37/0.19, accuracy (train/val): 0.83/0.94
# epoch: 58/200, loss (train/val): 0.30/0.19, accuracy (train/val): 0.85/0.93
# epoch: 59/200, loss (train/val): 0.31/0.19, accuracy (train/val): 0.86/0.93
# epoch: 60/200, loss (train/val): 0.36/0.19, accuracy (train/val): 0.83/0.93
# epoch: 61/200, loss (train/val): 0.30/0.19, accuracy (train/val): 0.87/0.93
# epoch: 62/200, loss (train/val): 0.38/0.19, accuracy (train/val): 0.83/0.93
# epoch: 63/200, loss (train/val): 0.35/0.19, accuracy (train/val): 0.84/0.93
# epoch: 64/200, loss (train/val): 0.39/0.20, accuracy (train/val): 0.80/0.95
# epoch: 65/200, loss (train/val): 0.32/0.20, accuracy (train/val): 0.87/0.94
# epoch: 66/200, loss (train/val): 0.38/0.21, accuracy (train/val): 0.81/0.93
# epoch: 67/200, loss (train/val): 0.45/0.22, accuracy (train/val): 0.80/0.93
# epoch: 68/200, loss (train/val): 0.36/0.22, accuracy (train/val): 0.85/0.92
# epoch: 69/200, loss (train/val): 0.39/0.22, accuracy (train/val): 0.82/0.93
# epoch: 70/200, loss (train/val): 0.40/0.21, accuracy (train/val): 0.79/0.93
# epoch: 71/200, loss (train/val): 0.30/0.20, accuracy (train/val): 0.87/0.93
# epoch: 72/200, loss (train/val): 0.37/0.19, accuracy (train/val): 0.82/0.93
# epoch: 73/200, loss (train/val): 0.38/0.18, accuracy (train/val): 0.82/0.93
# epoch: 74/200, loss (train/val): 0.37/0.18, accuracy (train/val): 0.82/0.93
# epoch: 75/200, loss (train/val): 0.34/0.19, accuracy (train/val): 0.86/0.94
# epoch: 76/200, loss (train/val): 0.35/0.19, accuracy (train/val): 0.82/0.94
# epoch: 77/200, loss (train/val): 0.37/0.18, accuracy (train/val): 0.82/0.95
# epoch: 78/200, loss (train/val): 0.36/0.19, accuracy (train/val): 0.83/0.95
# epoch: 79/200, loss (train/val): 0.33/0.19, accuracy (train/val): 0.85/0.94
# epoch: 80/200, loss (train/val): 0.31/0.18, accuracy (train/val): 0.87/0.95
# epoch: 81/200, loss (train/val): 0.30/0.17, accuracy (train/val): 0.87/0.94
# epoch: 82/200, loss (train/val): 0.41/0.17, accuracy (train/val): 0.82/0.94
# epoch: 83/200, loss (train/val): 0.31/0.18, accuracy (train/val): 0.85/0.93
# epoch: 84/200, loss (train/val): 0.35/0.18, accuracy (train/val): 0.82/0.93
# epoch: 85/200, loss (train/val): 0.31/0.18, accuracy (train/val): 0.84/0.94
# epoch: 86/200, loss (train/val): 0.31/0.17, accuracy (train/val): 0.82/0.94
# epoch: 87/200, loss (train/val): 0.31/0.17, accuracy (train/val): 0.84/0.94
# epoch: 88/200, loss (train/val): 0.34/0.16, accuracy (train/val): 0.84/0.95
# epoch: 89/200, loss (train/val): 0.36/0.16, accuracy (train/val): 0.83/0.95
# epoch: 90/200, loss (train/val): 0.37/0.17, accuracy (train/val): 0.84/0.94
# epoch: 91/200, loss (train/val): 0.34/0.18, accuracy (train/val): 0.83/0.94
# epoch: 92/200, loss (train/val): 0.31/0.18, accuracy (train/val): 0.85/0.93
# epoch: 93/200, loss (train/val): 0.30/0.17, accuracy (train/val): 0.87/0.95
# epoch: 94/200, loss (train/val): 0.28/0.17, accuracy (train/val): 0.87/0.94
# epoch: 95/200, loss (train/val): 0.35/0.16, accuracy (train/val): 0.85/0.94
# epoch: 96/200, loss (train/val): 0.33/0.18, accuracy (train/val): 0.86/0.95
# epoch: 97/200, loss (train/val): 0.27/0.18, accuracy (train/val): 0.87/0.95
# epoch: 98/200, loss (train/val): 0.34/0.17, accuracy (train/val): 0.85/0.94
# epoch: 99/200, loss (train/val): 0.33/0.18, accuracy (train/val): 0.86/0.94
# epoch: 100/200, loss (train/val): 0.32/0.18, accuracy (train/val): 0.85/0.95
# epoch: 101/200, loss (train/val): 0.35/0.19, accuracy (train/val): 0.84/0.93
# epoch: 102/200, loss (train/val): 0.36/0.19, accuracy (train/val): 0.84/0.93
# epoch: 103/200, loss (train/val): 0.35/0.18, accuracy (train/val): 0.83/0.93
# stopped early after 102 epoch(s)...
# using best epoch at [i=51, acc_val=0.95]

# %%
# plot + test + log results to file

with torch.no_grad():
	acc_test = epoch(model, test_loader, criterion)[1]
print(f"accuracy on test data: {acc_test*100.0}%")

fig = plot_train_history(stats, acc_test)
log_results(model, stats, fig, id)
# Out:
# accuracy on test data: 96.66666666666667%
